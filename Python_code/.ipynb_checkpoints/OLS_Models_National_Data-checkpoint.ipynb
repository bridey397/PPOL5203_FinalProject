# %% [markdown]
# Jupyter notebook for the OLS models based on the national dataset

# %% [markdown]
# # PPOL 5203 Final Project

# %% [markdown]
# ## Creating OLS Models

# %%
#!pip install openpyxl

# %%
import pandas as pd
import os
import openpyxl
import math
import seaborn as sns
import matplotlib.pyplot as plt 
from matplotlib.pyplot import figure
import numpy as np
from scipy import stats as st

# %%
# import library for models
import statsmodels.api as sm
import statsmodels.formula.api as smf
from plotnine import * # to imitate ggplot
from statsmodels.stats.anova import anova_lm
import statsmodels.api as sm
from stargazer.stargazer import Stargazer, LineLocation
from IPython.core.display import HTML
from pystout import pystout

# %%
pwd
# Out:
# '/Users/katharynloweth/Desktop/Data_Science_I_Fall2023/PPOL5203_FinalProject'

# %%
#should be in the PPOL5203 folder not in subfolder
os.chdir("../")

# %%
Merged_County_Data_clean = pd.read_csv('Datasets/Clean_Data/NRI_county_health_data.csv', header=0)

# %%
Merged_County_Data_clean.columns
# Out:
# Index(['FIPS', 'STATEABBRV', 'State', 'County', 'County_State',
#        'Community_Type', 'POPULATION', 'AREA', 'Population_Density',
#        'Percent_Rural', 'RISK_SCORE', 'RISK_RATNG', 'EAL_SCORE', 'EAL_RATNG',
#        'SOVI_SCORE', 'SOVI_RATNG', 'RESL_SCORE', 'RESL_RATNG',
#        'Percent_Fair_or_Poor_Health',
#        'Average_Number_of_Physically_Unhealthy_Days',
#        'Average_Number_of_Mentally_Unhealthy_Days',
#        'Number_Primary_Care_Physicians', 'Primary_Care_Physicians_Rate',
#        'Primary_Care_Physicians_Ratio', 'Number_Dentists', 'Dentist_Rate',
#        'Dentist_Ratio', 'Number_Mental_Health_Providers',
#        'Mental_Health_Provider_Rate', 'Mental_Health_Provider_Ratio',
#        'Average_Daily_PM2.5', 'Presence_of_Water_Violation', 'Life_Expectancy',
#        'Age-Adjusted_Death_Rate', 'Percent_Frequent_Physical_Distress',
#        'Percent_Frequent_Mental_Distress', 'Percent_Less_than_18_Years_of_Age',
#        'Percent_65_and_Over', 'Percent_Non-Hispanic_White', 'Percent_Female',
#        'Geolocation'],
#       dtype='object')

# %%
Merged_County_Data_clean["RISK_SCORE_SQ"] = Merged_County_Data_clean["RISK_SCORE"]**2

# %% [markdown]
# ## OLS Using Data on All U.S. Counties

# %% [markdown]
# **Life Expectancy and Risk Score**

# %%
life_ex_model_ols_r_bivariate = smf.ols(formula='Life_Expectancy ~ RISK_SCORE', data=Merged_County_Data_clean).fit()

print(life_ex_model_ols_r_bivariate.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     10.01
# Date:                Wed, 29 Nov 2023   Prob (F-statistic):            0.00157
# Time:                        12:03:28   Log-Likelihood:                -7986.7
# No. Observations:                3071   AIC:                         1.598e+04
# Df Residuals:                    3069   BIC:                         1.599e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     76.5603      0.121    632.298      0.000      76.323      76.798
# RISK_SCORE     0.0066      0.002      3.164      0.002       0.002       0.011
# ==============================================================================
# Omnibus:                      656.801   Durbin-Watson:                   1.380
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7720.966
# Skew:                           0.670   Prob(JB):                         0.00
# Kurtosis:                      10.651   Cond. No.                         120.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
life_ex_model_ols_r_mv1 = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + Population_Density', data=Merged_County_Data_clean).fit()


print(life_ex_model_ols_r_mv1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     19.41
# Date:                Wed, 29 Nov 2023   Prob (F-statistic):           4.20e-09
# Time:                        12:03:43   Log-Likelihood:                -7972.4
# No. Observations:                3071   AIC:                         1.595e+04
# Df Residuals:                    3068   BIC:                         1.597e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept             76.6016      0.121    634.195      0.000      76.365      76.838
# RISK_SCORE             0.0046      0.002      2.217      0.027       0.001       0.009
# Population_Density     0.0002   4.53e-05      5.359      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      657.768   Durbin-Watson:                   1.387
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7947.981
# Skew:                           0.663   Prob(JB):                         0.00
# Kurtosis:                      10.769   Cond. No.                     2.75e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.75e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
life_ex_model_ols_r_sq = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + RISK_SCORE_SQ + Population_Density + Community_Type', data=Merged_County_Data_clean).fit()


print(life_ex_model_ols_r_sq.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     49.09
# Date:                Mon, 04 Dec 2023   Prob (F-statistic):           4.89e-49
# Time:                        22:04:58   Log-Likelihood:                -7873.4
# No. Observations:                3071   AIC:                         1.576e+04
# Df Residuals:                    3065   BIC:                         1.579e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        77.4925      0.185    417.884      0.000      77.129      77.856
# Community_Type[T.Small Urban]     1.3307      0.165      8.073      0.000       1.008       1.654
# Community_Type[T.Urban]           3.2194      0.291     11.067      0.000       2.649       3.790
# RISK_SCORE                       -0.0374      0.009     -4.268      0.000      -0.055      -0.020
# RISK_SCORE_SQ                     0.0002   9.01e-05      2.248      0.025    2.59e-05       0.000
# Population_Density             8.579e-05   4.56e-05      1.881      0.060   -3.62e-06       0.000
# ==============================================================================
# Omnibus:                      749.378   Durbin-Watson:                   1.436
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10088.872
# Skew:                           0.775   Prob(JB):                         0.00
# Kurtosis:                      11.743   Cond. No.                     2.44e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.44e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
life_ex_model_ols_r_mv2 = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + Population_Density + Community_Type', data=Merged_County_Data_clean).fit()


print(life_ex_model_ols_r_mv2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     60.02
# Date:                Wed, 29 Nov 2023   Prob (F-statistic):           7.16e-49
# Time:                        12:03:43   Log-Likelihood:                -7875.9
# No. Observations:                3071   AIC:                         1.576e+04
# Df Residuals:                    3066   BIC:                         1.579e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        77.1826      0.124    621.745      0.000      76.939      77.426
# Community_Type[T.Small Urban]     1.3962      0.162      8.600      0.000       1.078       1.714
# Community_Type[T.Urban]           3.5300      0.256     13.780      0.000       3.028       4.032
# RISK_SCORE                       -0.0186      0.003     -6.967      0.000      -0.024      -0.013
# Population_Density             8.861e-05   4.56e-05      1.943      0.052   -8.16e-07       0.000
# ==============================================================================
# Omnibus:                      759.074   Durbin-Watson:                   1.433
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10345.402
# Skew:                           0.786   Prob(JB):                         0.00
# Kurtosis:                      11.853   Cond. No.                     6.41e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
#comparing population vs population_density in model
life_ex_model_ols_r_mv3 = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + Population_Density + Community_Type', data=Merged_County_Data_clean).fit()


print(life_ex_model_ols_r_mv3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.071
# Method:                 Least Squares   F-statistic:                     60.02
# Date:                Wed, 29 Nov 2023   Prob (F-statistic):           7.16e-49
# Time:                        12:04:17   Log-Likelihood:                -7875.9
# No. Observations:                3071   AIC:                         1.576e+04
# Df Residuals:                    3066   BIC:                         1.579e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        77.1826      0.124    621.745      0.000      76.939      77.426
# Community_Type[T.Small Urban]     1.3962      0.162      8.600      0.000       1.078       1.714
# Community_Type[T.Urban]           3.5300      0.256     13.780      0.000       3.028       4.032
# RISK_SCORE                       -0.0186      0.003     -6.967      0.000      -0.024      -0.013
# Population_Density             8.861e-05   4.56e-05      1.943      0.052   -8.16e-07       0.000
# ==============================================================================
# Omnibus:                      759.074   Durbin-Watson:                   1.433
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10345.402
# Skew:                           0.786   Prob(JB):                         0.00
# Kurtosis:                      11.853   Cond. No.                     6.41e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.41e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
life_ex_model_ols_r_int = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + Population_Density + Community_Type + RISK_SCORE*Community_Type', data=Merged_County_Data_clean).fit()


print(life_ex_model_ols_r_int.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     41.09
# Date:                Thu, 30 Nov 2023   Prob (F-statistic):           2.15e-48
# Time:                        16:21:04   Log-Likelihood:                -7872.9
# No. Observations:                3071   AIC:                         1.576e+04
# Df Residuals:                    3064   BIC:                         1.580e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                   77.2910      0.133    583.313      0.000      77.031      77.551
# Community_Type[T.Small Urban]                0.3992      0.507      0.787      0.432      -0.596       1.394
# Community_Type[T.Urban]                     -0.0989      2.713     -0.036      0.971      -5.418       5.220
# RISK_SCORE                                  -0.0214      0.003     -7.310      0.000      -0.027      -0.016
# RISK_SCORE:Community_Type[T.Small Urban]     0.0153      0.007      2.098      0.036       0.001       0.030
# RISK_SCORE:Community_Type[T.Urban]           0.0410      0.029      1.392      0.164      -0.017       0.099
# Population_Density                        8.163e-05   4.59e-05      1.780      0.075   -8.29e-06       0.000
# ==============================================================================
# Omnibus:                      755.593   Durbin-Watson:                   1.437
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10357.356
# Skew:                           0.779   Prob(JB):                         0.00
# Kurtosis:                      11.861   Cond. No.                     6.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Age Adjusted Death Rate**

# %%
#won't run till we fix code

#dr_model_ols_r1 = smf.ols(formula='Age ~ RISK_SCORE + Population_Density + Community_Type + RISK_SCORE*Community_Type ', data=Merged_County_Data_clean).fit()
#
#print(dr_model_ols_r1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.073
# Method:                 Least Squares   F-statistic:                     41.09
# Date:                Thu, 30 Nov 2023   Prob (F-statistic):           2.15e-48
# Time:                        16:27:09   Log-Likelihood:                -7872.9
# No. Observations:                3071   AIC:                         1.576e+04
# Df Residuals:                    3064   BIC:                         1.580e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                   77.2910      0.133    583.313      0.000      77.031      77.551
# Community_Type[T.Small Urban]                0.3992      0.507      0.787      0.432      -0.596       1.394
# Community_Type[T.Urban]                     -0.0989      2.713     -0.036      0.971      -5.418       5.220
# RISK_SCORE                                  -0.0214      0.003     -7.310      0.000      -0.027      -0.016
# RISK_SCORE:Community_Type[T.Small Urban]     0.0153      0.007      2.098      0.036       0.001       0.030
# RISK_SCORE:Community_Type[T.Urban]           0.0410      0.029      1.392      0.164      -0.017       0.099
# Population_Density                        8.163e-05   4.59e-05      1.780      0.075   -8.29e-06       0.000
# ==============================================================================
# Omnibus:                      755.593   Durbin-Watson:                   1.437
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10357.356
# Skew:                           0.779   Prob(JB):                         0.00
# Kurtosis:                      11.861   Cond. No.                     6.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
dr_model_ols_r_sq = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + RISK_SCORE_SQ + Community_Type', data=Southeast_county_data).fit()

print(dr_model_ols_r_sq.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.197
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     56.36
# Date:                Mon, 04 Dec 2023   Prob (F-statistic):           1.56e-42
# Time:                        22:05:26   Log-Likelihood:                -2199.8
# No. Observations:                 922   AIC:                             4410.
# Df Residuals:                     917   BIC:                             4434.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        75.7888      0.282    269.111      0.000      75.236      76.342
# Community_Type[T.Small Urban]     2.0621      0.240      8.581      0.000       1.590       2.534
# Community_Type[T.Urban]           4.1987      0.452      9.285      0.000       3.311       5.086
# RISK_SCORE                       -0.0618      0.013     -4.685      0.000      -0.088      -0.036
# RISK_SCORE_SQ                     0.0005      0.000      3.918      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                       65.095   Durbin-Watson:                   1.619
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.006
# Skew:                           0.360   Prob(JB):                     2.70e-38
# Kurtosis:                       4.996   Cond. No.                     2.46e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
dr_model_ols_r_sq2 = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + RISK_SCORE_SQ + Community_Type + Population_Density', data=Southeast_county_data).fit()

print(dr_model_ols_r_sq2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     56.87
# Date:                Mon, 04 Dec 2023   Prob (F-statistic):           1.45e-51
# Time:                        22:05:52   Log-Likelihood:                -2176.5
# No. Observations:                 922   AIC:                             4365.
# Df Residuals:                     916   BIC:                             4394.
# Df Model:                           5
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        75.5978      0.276    273.763      0.000      75.056      76.140
# Community_Type[T.Small Urban]     1.7899      0.238      7.529      0.000       1.323       2.257
# Community_Type[T.Urban]           3.4257      0.455      7.526      0.000       2.532       4.319
# RISK_SCORE                       -0.0604      0.013     -4.698      0.000      -0.086      -0.035
# RISK_SCORE_SQ                     0.0005      0.000      4.078      0.000       0.000       0.001
# Population_Density                0.0009      0.000      6.891      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       20.659   Durbin-Watson:                   1.597
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               39.590
# Skew:                           0.085   Prob(JB):                     2.53e-09
# Kurtosis:                       4.001   Cond. No.                     2.54e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.54e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
dr_model_ols_r_int = smf.ols(formula='Life_Expectancy ~ RISK_SCORE + RISK_SCORE_SQ + Community_Type + Population_Density + Community_Type*RISK_SCORE', data=Southeast_county_data).fit()

print(dr_model_ols_r_int.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Life_Expectancy   R-squared:                       0.238
# Model:                            OLS   Adj. R-squared:                  0.233
# Method:                 Least Squares   F-statistic:                     40.87
# Date:                Mon, 04 Dec 2023   Prob (F-statistic):           3.40e-50
# Time:                        22:06:20   Log-Likelihood:                -2175.6
# No. Observations:                 922   AIC:                             4367.
# Df Residuals:                     914   BIC:                             4406.
# Df Model:                           7
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                   75.6837      0.284    266.266      0.000      75.126      76.242
# Community_Type[T.Small Urban]                2.4717      0.812      3.043      0.002       0.877       4.066
# Community_Type[T.Urban]                      9.2681      5.260      1.762      0.078      -1.054      19.590
# RISK_SCORE                                  -0.0686      0.015     -4.695      0.000      -0.097      -0.040
# Community_Type[T.Small Urban]:RISK_SCORE    -0.0109      0.012     -0.897      0.370      -0.035       0.013
# Community_Type[T.Urban]:RISK_SCORE          -0.0658      0.057     -1.149      0.251      -0.178       0.047
# RISK_SCORE_SQ                                0.0006      0.000      3.956      0.000       0.000       0.001
# Population_Density                           0.0009      0.000      6.875      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                       20.850   Durbin-Watson:                   1.602
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.021
# Skew:                           0.087   Prob(JB):                     2.04e-09
# Kurtosis:                       4.006   Cond. No.                     2.84e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.84e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# **Mentally Unhealthy Days and Risk Score**

# %%
model_ols_r_mh1 = smf.ols(formula='Average_Number_of_Mentally_Unhealthy_Days ~ RISK_SCORE + Population_Density + Community_Type + RISK_SCORE*Community_Type', data=Merged_County_Data_clean).fit()


print(model_ols_r_mh1.summary())
# Out:
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Average_Number_of_Mentally_Unhealthy_Days   R-squared:                       0.013
# Model:                                                   OLS   Adj. R-squared:                  0.011
# Method:                                        Least Squares   F-statistic:                     6.950
# Date:                                       Sun, 03 Dec 2023   Prob (F-statistic):           2.36e-07
# Time:                                               19:20:51   Log-Likelihood:                -2971.6
# No. Observations:                                       3140   AIC:                             5957.
# Df Residuals:                                           3133   BIC:                             6000.
# Df Model:                                                  6
# Covariance Type:                                   nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    4.7135      0.025    187.815      0.000       4.664       4.763
# Community_Type[T.Small Urban]                0.2767      0.100      2.757      0.006       0.080       0.474
# Community_Type[T.Urban]                     -0.3612      0.538     -0.671      0.502      -1.417       0.694
# RISK_SCORE                                   0.0024      0.001      4.211      0.000       0.001       0.003
# RISK_SCORE:Community_Type[T.Small Urban]    -0.0043      0.001     -2.983      0.003      -0.007      -0.001
# RISK_SCORE:Community_Type[T.Urban]           0.0011      0.006      0.190      0.849      -0.010       0.013
# Population_Density                       -1.255e-05    9.1e-06     -1.379      0.168   -3.04e-05    5.29e-06
# ==============================================================================
# Omnibus:                        2.505   Durbin-Watson:                   0.455
# Prob(Omnibus):                  0.286   Jarque-Bera (JB):                2.551
# Skew:                          -0.060   Prob(JB):                        0.279
# Kurtosis:                       2.930   Cond. No.                     6.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
small_urban_int_mh1 = model_ols_r_mh1.params.iloc[0:2].sum() 
urban_int_mh1 = model_ols_r_mh1.params.iloc[0] + model_ols_r_mh1.params.iloc[2]
rural_int_mh1 = model_ols_r_mh1.params.iloc[0]

small_urban_slope_mh1 = model_ols_r_mh1.params.iloc[3] + model_ols_r_mh1.params.iloc[4]
urban_slope_mh1 = model_ols_r_mh1.params.iloc[3] + model_ols_r_mh1.params.iloc[5]
rural_slope_mh1 = model_ols_r_mh1.params.iloc[3]

# %%
lines_data_mh1 = pd.DataFrame({'intercept': [rural_int_mh1, small_urban_int_mh1, urban_int_mh1],
'slope':[rural_slope_mh1, small_urban_slope_mh1, urban_slope_mh1],
'Community_Type':['Rural', 'Small Urban', 'Urban']})
plot_mh_line_1 = (ggplot(Merged_County_Data_clean) + 
                  aes(x = 'RISK_SCORE', y = 'Average_Number_of_Mentally_Unhealthy_Days', fill = "Community_Type") + 
                  geom_point()  + facet_wrap('Community_Type') + theme(figure_size = (10,6 )))
plot_mh_line_1 + geom_abline(aes(intercept='intercept', slope='slope'), data = lines_data_mh1[lines_data_mh1['Community_Type'] == 'Rural'], color = 'red') + geom_abline(aes(intercept='intercept', slope='slope'), data = lines_data_mh1[lines_data_mh1['Community_Type'] == 'Small Urban'], color = "green")+ geom_abline(aes(intercept='intercept', slope='slope'), data = lines_data_mh1[lines_data_mh1['Community_Type'] == 'Urban'], color = "blue")
# Out:
# C:\Users\bsullivan\.conda\envs\ppol5203\Lib\site-packages\plotnine\layer.py:364: PlotnineWarning: geom_point : Removed 3 rows containing missing values.
# <Figure Size: (1000 x 600)>

# %%
sns.scatterplot(data=Merged_County_Data_clean, x="RISK_SCORE", y="Average_Number_of_Mentally_Unhealthy_Days").set(title = "Average Number of Mentally Unhealthy Days - All Data")

plt.show()

fig1 = plt.gcf()
plt.show()
fig1.savefig('Final_Results/Mentally_Unhealthy_Days_Scatterplot_AllData.png')

# %%
model_ols_r_mh_sq = smf.ols(formula='Average_Number_of_Mentally_Unhealthy_Days ~ RISK_SCORE + RISK_SCORE_SQ + Population_Density + Community_Type + RISK_SCORE*Community_Type', data=Merged_County_Data_clean).fit()


print(model_ols_r_mh_sq.summary())
# Out:
#                                         OLS Regression Results
# =====================================================================================================
# Dep. Variable:     Average_Number_of_Mentally_Unhealthy_Days   R-squared:                       0.014
# Model:                                                   OLS   Adj. R-squared:                  0.012
# Method:                                        Least Squares   F-statistic:                     6.288
# Date:                                       Mon, 04 Dec 2023   Prob (F-statistic):           2.39e-07
# Time:                                               22:06:49   Log-Likelihood:                -2970.5
# No. Observations:                                       3140   AIC:                             5957.
# Df Residuals:                                           3132   BIC:                             6005.
# Df Model:                                                  7
# Covariance Type:                                   nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    4.7514      0.035    134.141      0.000       4.682       4.821
# Community_Type[T.Small Urban]                0.3706      0.118      3.143      0.002       0.139       0.602
# Community_Type[T.Urban]                     -0.1374      0.558     -0.246      0.805      -1.232       0.957
# RISK_SCORE                                  -0.0004      0.002     -0.214      0.831      -0.004       0.003
# RISK_SCORE:Community_Type[T.Small Urban]    -0.0059      0.002     -3.301      0.001      -0.009      -0.002
# RISK_SCORE:Community_Type[T.Urban]          -0.0021      0.006     -0.332      0.740      -0.014       0.010
# RISK_SCORE_SQ                             3.363e-05   2.22e-05      1.516      0.130   -9.86e-06    7.71e-05
# Population_Density                       -1.246e-05    9.1e-06     -1.370      0.171   -3.03e-05    5.38e-06
# ==============================================================================
# Omnibus:                        2.089   Durbin-Watson:                   0.456
# Prob(Omnibus):                  0.352   Jarque-Bera (JB):                2.139
# Skew:                          -0.055   Prob(JB):                        0.343
# Kurtosis:                       2.936   Cond. No.                     2.25e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.25e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
conf_int_mh1 = pd.DataFrame({'estimate': model_ols_r_mh1.params, 'lower': model_ols_r_mh1.params - model_ols_r_mh1.bse*3, 'upper':model_ols_r_mh1.params + model_ols_r_mh1.bse*3})
#conf_int_ph1['coefficient'] = conf_int_ph1.index
conf_int_mh1 = conf_int_mh1.reset_index().rename( columns = {'index': 'coefficient'})
conf_int_mh1
# Out:
#                                 coefficient  estimate     lower     upper
# 0                                 Intercept  4.713471  4.638182  4.788760
# 1             Community_Type[T.Small Urban]  0.276725 -0.024430  0.577880
# 2                   Community_Type[T.Urban] -0.361166 -1.975975  1.253644
# 3                                RISK_SCORE  0.002373  0.000682  0.004063
# 4  RISK_SCORE:Community_Type[T.Small Urban] -0.004290 -0.008604  0.000025
# 5        RISK_SCORE:Community_Type[T.Urban]  0.001110 -0.016434  0.018654
# 6                        Population_Density -0.000013 -0.000040  0.000015

# %%
ggplot(conf_int_mh1) + geom_errorbar(aes(x = conf_int_mh1['coefficient'], y =conf_int_mh1['estimate'], ymin =conf_int_mh1['lower'], ymax =conf_int_mh1['upper'])) + theme(axis_text_x=element_text(rotation=65, hjust=1))
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# **Physically Unhealthy Days and Risk Score**

# %%
model_ols_r_ph1 = smf.ols(formula='Average_Number_of_Physically_Unhealthy_Days ~ RISK_SCORE + Population_Density + Community_Type + RISK_SCORE*Community_Type', data=Merged_County_Data_clean).fit()


print(model_ols_r_ph1.summary())
# Out:
#                                          OLS Regression Results
# =======================================================================================================
# Dep. Variable:     Average_Number_of_Physically_Unhealthy_Days   R-squared:                       0.089
# Model:                                                     OLS   Adj. R-squared:                  0.087
# Method:                                          Least Squares   F-statistic:                     51.11
# Date:                                         Mon, 04 Dec 2023   Prob (F-statistic):           2.95e-60
# Time:                                                 22:40:37   Log-Likelihood:                -2965.0
# No. Observations:                                         3140   AIC:                             5944.
# Df Residuals:                                             3133   BIC:                             5986.
# Df Model:                                                    6
# Covariance Type:                                     nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    3.4875      0.025    139.258      0.000       3.438       3.537
# Community_Type[T.Small Urban]               -0.2789      0.100     -2.784      0.005      -0.475      -0.082
# Community_Type[T.Urban]                     -1.7770      0.537     -3.308      0.001      -2.830      -0.724
# RISK_SCORE                                   0.0037      0.001      6.606      0.000       0.003       0.005
# RISK_SCORE:Community_Type[T.Small Urban]    -0.0013      0.001     -0.907      0.365      -0.004       0.002
# RISK_SCORE:Community_Type[T.Urban]           0.0114      0.006      1.959      0.050   -1.05e-05       0.023
# Population_Density                       -2.637e-05   9.08e-06     -2.903      0.004   -4.42e-05   -8.56e-06
# ==============================================================================
# Omnibus:                       90.335   Durbin-Watson:                   0.747
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               98.492
# Skew:                           0.409   Prob(JB):                     4.10e-22
# Kurtosis:                       3.291   Cond. No.                     6.37e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.37e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
small_urban_int_ph1 = model_ols_r_ph1.params.iloc[0:2].sum() 
urban_int_ph1 = model_ols_r_ph1.params.iloc[0] + model_ols_r_ph1.params.iloc[2]
rural_int_ph1 = model_ols_r_ph1.params.iloc[0]

small_urban_slope_ph1 = model_ols_r_ph1.params.iloc[3] + model_ols_r_ph1.params.iloc[4]
urban_slope_ph1 = model_ols_r_ph1.params.iloc[3] + model_ols_r_ph1.params.iloc[5]
rural_slope_ph1 = model_ols_r_ph1.params.iloc[3]

# %%
lines_data_ph1 = pd.DataFrame({'intercept': [rural_int_ph1, small_urban_int_ph1, urban_int_ph1],
'slope':[rural_slope_ph1, small_urban_slope_ph1, urban_slope_ph1],
'Community_Type':['Rural', 'Small Urban', 'Urban']})
plot_ph1_line_1 = (ggplot(Merged_County_Data_clean) + 
                  aes(x = 'RISK_SCORE', y = 'Average_Number_of_Physically_Unhealthy_Days', fill = "Community_Type") + 
                  geom_point()  + facet_wrap('Community_Type') + theme(figure_size = (10,6 )))
plot_ph1_line_1 + geom_abline(aes(intercept='intercept', slope='slope'), data = lines_data_ph1[lines_data_ph1['Community_Type'] == 'Rural'], color = 'red') + geom_abline(aes(intercept='intercept', slope='slope'), data = lines_data_ph1[lines_data_ph1['Community_Type'] == 'Small Urban'], color = "green")+ geom_abline(aes(intercept='intercept', slope='slope'), data = lines_data_ph1[lines_data_ph1['Community_Type'] == 'Urban'], color = "blue")
# Out:
# C:\Users\bsullivan\.conda\envs\ppol5203\Lib\site-packages\plotnine\layer.py:364: PlotnineWarning: geom_point : Removed 3 rows containing missing values.
# <Figure Size: (1000 x 600)>

# %%
conf_int_ph1 = pd.DataFrame({'estimate': model_ols_r_ph1.params, 'lower': model_ols_r_ph1.params - model_ols_r_ph1.bse*3, 'upper':model_ols_r_ph1.params + model_ols_r_ph1.bse*3})
#conf_int_ph1['coefficient'] = conf_int_ph1.index
conf_int_ph1 = conf_int_ph1.reset_index().rename( columns = {'index': 'coefficient'})
conf_int_ph1
# Out:
#                                 coefficient  estimate     lower         upper
# 0                                 Intercept  3.487548  3.412416  3.562679e+00
# 1             Community_Type[T.Small Urban] -0.278903 -0.579427  2.162207e-02
# 2                   Community_Type[T.Urban] -1.776951 -3.388379 -1.655229e-01
# 3                                RISK_SCORE  0.003714  0.002027  5.400950e-03
# 4  RISK_SCORE:Community_Type[T.Small Urban] -0.001301 -0.005607  3.003942e-03
# 5        RISK_SCORE:Community_Type[T.Urban]  0.011432 -0.006075  2.893914e-02
# 6                        Population_Density -0.000026 -0.000054  8.770148e-07

# %%
ggplot(conf_int_ph1) + geom_errorbar(aes(x = conf_int_ph1['coefficient'], y =conf_int_ph1['estimate'], ymin =conf_int_ph1['lower'], ymax =conf_int_ph1['upper'])) + theme(axis_text_x=element_text(rotation=25, hjust=1))
# Out:
# <Figure Size: (640 x 480)>

# %%
model_ols_r_ph_sq = smf.ols(formula='Average_Number_of_Physically_Unhealthy_Days ~ RISK_SCORE + RISK_SCORE_SQ + Population_Density + Community_Type + RISK_SCORE*Community_Type', data=Merged_County_Data_clean).fit()


print(model_ols_r_ph_sq.summary())
# Out:
#                                          OLS Regression Results
# =======================================================================================================
# Dep. Variable:     Average_Number_of_Physically_Unhealthy_Days   R-squared:                       0.091
# Model:                                                     OLS   Adj. R-squared:                  0.088
# Method:                                          Least Squares   F-statistic:                     44.52
# Date:                                         Mon, 04 Dec 2023   Prob (F-statistic):           2.23e-60
# Time:                                                 22:07:23   Log-Likelihood:                -2962.7
# No. Observations:                                         3140   AIC:                             5941.
# Df Residuals:                                             3132   BIC:                             5990.
# Df Model:                                                    7
# Covariance Type:                                     nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    3.5414      0.035    100.227      0.000       3.472       3.611
# Community_Type[T.Small Urban]               -0.1457      0.118     -1.239      0.216      -0.376       0.085
# Community_Type[T.Urban]                     -1.4593      0.557     -2.622      0.009      -2.551      -0.368
# RISK_SCORE                                  -0.0002      0.002     -0.123      0.902      -0.004       0.004
# RISK_SCORE:Community_Type[T.Small Urban]    -0.0036      0.002     -2.012      0.044      -0.007   -9.09e-05
# RISK_SCORE:Community_Type[T.Urban]           0.0069      0.006      1.118      0.263      -0.005       0.019
# RISK_SCORE_SQ                             4.774e-05   2.21e-05      2.158      0.031    4.36e-06    9.11e-05
# Population_Density                       -2.624e-05   9.08e-06     -2.892      0.004    -4.4e-05   -8.45e-06
# ==============================================================================
# Omnibus:                       95.459   Durbin-Watson:                   0.750
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              104.724
# Skew:                           0.420   Prob(JB):                     1.82e-23
# Kurtosis:                       3.309   Cond. No.                     2.25e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.25e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
anova_results = anova_lm(model_ols_r_ph1, model_ols_r_ph_sq)
print(anova_results)
# Out:
#    df_resid          ssr  df_diff   ss_diff         F  Pr(>F)
# 0    3133.0  1215.185247      0.0       NaN       NaN     NaN
# 1    3134.0  1215.969053     -1.0 -0.783805  2.020155     NaN
